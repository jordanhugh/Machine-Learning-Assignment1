# %%
# %run Assignment1.py
# Out:
# Parameter Values
# α      e0           e1
# 0.000  0.00000000   0.00000000
# 0.001  -0.00000000  -0.31141844
# 0.010  -0.00000000  -0.92723967
# 0.100  -0.00000000  -0.94383988
#
# Cost Function
# α      J(θ)
# 0.000  1.00000000
# 0.001  0.51072780
# 0.010  0.10945322
# 0.100  0.10916629
# Sklearn Parameter Values:
# Model                    Intercept        Coefficient
# Gradient Descent(α=0.1)  -3.24853062e-16  -0.94383988
# Sklearn                  -3.97885432e-16  -0.94383988
